# %%
#1 user login check

#stored login creditionals
username="Shankar"
password="0747"

#inputs
username=input("enter the username:")
password=input("enter the password:")
#using if condition to check the inputs
if username=="Shankar" and password=="0747":
    print("login successful")
else:
    print("invalid creditionals")
# Out:
# enter the username: Shankar
# enter the password: 0747
# login successful

# %%
#2. pass/fail Analyzer
marks=[45,78,90,33,60]
pass_count=0
fail_count=0
for i in marks:
    if i >=50:
        pass_count+=1
    else:
        fail_count+=1 
print("total students:", len(marks))
print("Pass students:",pass_count)
print("Fail  students:",fail_count)
# Out:
# total students: 5
# Pass students: 3
# Fail  students: 2

# %%
#3. Data cleaning
names=[" Alice ", "bob", " CHARLIE "]
cleaned_names=[] #create empty list 
for name in names:
    cleaned_name=name.strip().lower()
    cleaned_names.append(cleaned_name)
print("cleaned names:",cleaned_names) # print the cleaned list
# Out:
# cleaned names: ['alice', 'bob', 'charlie']

# %%
# Message Length Analyzer

messages = ["Hi", "Welcome to the platform", "OK"]
for message in messages:
    length = len(message)       #length of message
    print("Message:", message)
    print("Length:", length)
    if length > 10:
        print("Flag:Message is longer than 10 characters")
    print()
# Out:
# Message: Hi
# Length: 2
#
# Message: Welcome to the platform
# Length: 23
# Flag:Message is longer than 10 characters
#
# Message: OK
# Length: 2

# %%
#5.error message detector
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

error_count = 0  # to store the error count

for log in logs:
    if log == "ERROR":
        error_count += 1
print("Total error entries:", error_count)
# Out:
# Total error entries: 2
